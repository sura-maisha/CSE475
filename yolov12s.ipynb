# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install --upgrade ultralytics --no-deps
# !pip install roboflow

from roboflow import Roboflow

rf = Roboflow(api_key="vM6qrOEJgCQAXNdbbGk0")

project = rf.workspace("objectdetection-tecsf").project("skysealand-wrqjn")
version = project.version(2)

# Correct dataset format
dataset = version.download("yolov8")
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.237-py3-none-any.whl.metadata (37 kB)
# Downloading ultralytics-8.3.237-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: ultralytics
# Successfully installed ultralytics-8.3.237
# Collecting roboflow
#   Downloading roboflow-1.2.11-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.10.5)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.7.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.26.4)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.3.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.1.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.5 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.5)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->roboflow) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->roboflow) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->roboflow) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->roboflow) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->roboflow) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.5->roboflow) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.59.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.0.9)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.4)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.5->roboflow) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.5->roboflow) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.5->roboflow) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.5->roboflow) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.18.5->roboflow) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.18.5->roboflow) (2024.2.0)
# Downloading roboflow-1.2.11-py3-none-any.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.0 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.1 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 39.5 MB/s eta 0:00:00:00:0100:01
# Downloading pi_heif-1.1.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 64.8 MB/s eta 0:00:00
# Downloading pillow_avif_plugin-1.5.2-cp311-cp311-manylinux_2_28_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 90.3 MB/s eta 0:00:00:00:01
# Installing collected packages: pillow-avif-plugin, pi-heif, idna, opencv-python-headless, roboflow
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# s3fs 2025.3.0 requires fsspec==2025.3.0.*, but you have fsspec 2025.10.0 which is incompatible.
# ray 2.51.1 requires click!=8.3.0,>=7.0, but you have click 8.3.0 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.0 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 46.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.3.0 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.0 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.6.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# Successfully installed idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.1.1 pillow-avif-plugin-1.5.2 roboflow-1.2.11
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Skysealand-2 to yolov8:: 100%|██████████| 269606/269606 [00:03<00:00, 81564.19it/s]
# Extracting Dataset Version Zip to Skysealand-2 in yolov8:: 100%|██████████| 2626/2626 [00:00<00:00, 3847.29it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

model = YOLO("yolo12s")  # choose nano version
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo12s.pt to 'yolo12s.pt': 100% ━━━━━━━━━━━━ 18.1MB 124.6MB/s 0.1s1s<0.2s

# %%
import os, gc, json, shutil, yaml, warnings, random, math, copy
from pathlib import Path
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from tqdm.auto import tqdm

from ultralytics import YOLO

# %%
import os

print(os.listdir("/kaggle/working"))
# Out:
# ['.virtual_documents', 'yolo12s.pt', 'Skysealand-2']

# %%
for item in os.listdir("/kaggle/working"):
    print(item)
# Out:
# .virtual_documents
# yolo12s.pt
# Skysealand-2

# %%
import os

base = "/kaggle/working"
dataset_dir = [d for d in os.listdir(base) if d.lower().startswith("sky")][0]

print("Dataset folder:", dataset_dir)

yaml_path = f"{base}/{dataset_dir}/data.yaml"

yaml_content = f"""
train: {base}/{dataset_dir}/train/images
val: {base}/{dataset_dir}/valid/images
test: {base}/{dataset_dir}/test/images

nc: 4
names:
  - Airplane
  - Boat
  - Car
  - Ship
"""

with open(yaml_path, "w") as f:
    f.write(yaml_content)

print("Data.yaml written to:", yaml_path)
# Out:
# Dataset folder: Skysealand-2
# Data.yaml written to: /kaggle/working/Skysealand-2/data.yaml

# %%
print(os.listdir(f"/kaggle/working/{dataset_dir}"))
# Out:
# ['test', 'data.yaml', 'README.dataset.txt', 'train', 'README.roboflow.txt', 'valid']

# %%
for root, dirs, files in os.walk("/kaggle/working"):
    if "data.yaml" in files:
        print(os.path.join(root, "data.yaml"))
# Out:
# /kaggle/working/Skysealand-2/data.yaml

# %%
import os, shutil

base_path = "/kaggle/working/Skysealand-2"

for folder in ['train', 'valid', 'test']:
    img_dir = os.path.join(base_path, folder, 'images')
    label_dir = os.path.join(base_path, folder, 'labels')
    os.makedirs(img_dir, exist_ok=True)
    os.makedirs(label_dir, exist_ok=True)

# move misplaced images from root into train/images if any
for f in os.listdir(base_path):
    if f.endswith('.jpg') or f.endswith('.png'):
        shutil.move(os.path.join(base_path, f), os.path.join(base_path, 'train/images', f))

print("Folder structure ready for YOLO training.")
# Out:
# Folder structure ready for YOLO training.

# %%
import os
os.listdir("/kaggle/working")
# Out:
# ['.virtual_documents', 'yolo12s.pt', 'Skysealand-2']

# %%
from ultralytics import YOLO
from pathlib import Path
import os

# Auto-detect SkySeaLand dataset folder
base = "/kaggle/working"
dataset_dir = [d for d in os.listdir(base) if "sky" in d.lower()][0]

DATA = f"{base}/{dataset_dir}/data.yaml"
OUTPUT_FOLDER = Path("/kaggle/working/yolo-output")

# Check YAML exists before training
if not Path(DATA).exists():
    raise FileNotFoundError(f"data.yaml not found at: {DATA}")

print("Using dataset:", DATA)

# Correct model name (YOLOv8)
model = YOLO("yolov8n.pt")

# Train model
model.train(
    data=DATA,
    epochs=50,
    imgsz=640,
    batch=16,
    workers=2,
    project=str(OUTPUT_FOLDER),
    name="train"
)

print("Training started successfully!")
# Out:
# Using dataset: /kaggle/working/Skysealand-2/data.yaml
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 69.3MB/s 0.1s
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/Skysealand-2/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo-output, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo-output/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 14.2MB/s 0.1s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752092  ultralytics.nn.modules.head.Detect           [4, [64, 128, 256]]
# Model summary: 129 layers, 3,011,628 parameters, 3,011,612 gradients
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 57.8MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2716.5±1641.9 MB/s, size: 219.4 KB)
# train: Scanning /kaggle/working/Skysealand-2/train/labels... 1048 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1048/1048 1.3Kit/s 0.8s1ss
# train: New cache created: /kaggle/working/Skysealand-2/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1047.6±1021.7 MB/s, size: 285.2 KB)
# val: Scanning /kaggle/working/Skysealand-2/valid/labels... 132 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 132/132 1.2Kit/s 0.1s<0.0s
# val: New cache created: /kaggle/working/Skysealand-2/valid/labels.cache
# Plotting labels to /kaggle/working/yolo-output/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/yolo-output/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      3.13G      1.842      2.984      1.145        121        640: 100% ━━━━━━━━━━━━ 66/66 4.6it/s 14.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 1.8it/s 2.7s0.4ss
#                    all        132       1992      0.696      0.169      0.345      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      4.05G      1.725      1.725      1.088        301        640: 100% ━━━━━━━━━━━━ 66/66 5.6it/s 11.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.2it/s 1.2s0.4s
#                    all        132       1992      0.545       0.53      0.517      0.255
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      4.07G      1.654      1.563      1.084        179        640: 100% ━━━━━━━━━━━━ 66/66 5.7it/s 11.7s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.8it/s 1.3s0.4s
#                    all        132       1992      0.621      0.515      0.551       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50       4.6G      1.612      1.426      1.063        275        640: 100% ━━━━━━━━━━━━ 66/66 5.6it/s 11.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.7it/s 1.1s0.3s
#                    all        132       1992      0.604      0.574      0.552      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      4.61G      1.599      1.343      1.059        267        640: 100% ━━━━━━━━━━━━ 66/66 5.7it/s 11.6s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.6it/s 1.1s0.3s
#                    all        132       1992      0.631      0.619      0.655      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50       5.2G      1.551      1.282      1.044        203        640: 100% ━━━━━━━━━━━━ 66/66 5.8it/s 11.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.3it/s 1.2s0.3s
#                    all        132       1992      0.655      0.643      0.653      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      5.21G      1.545       1.25      1.043        103        640: 100% ━━━━━━━━━━━━ 66/66 5.7it/s 11.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.7it/s 1.1s0.3s
#                    all        132       1992      0.684      0.635      0.672      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      5.24G      1.499      1.165      1.034        194        640: 100% ━━━━━━━━━━━━ 66/66 5.5it/s 11.9s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.4it/s 1.1s0.3s
#                    all        132       1992      0.713       0.62      0.676       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      5.24G      1.496       1.14      1.027        141        640: 100% ━━━━━━━━━━━━ 66/66 5.6it/s 11.8s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.7it/s 1.1s0.3s
#                    all        132       1992      0.693      0.656       0.69      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      5.27G       1.49      1.106      1.023        374        640: 100% ━━━━━━━━━━━━ 66/66 5.5it/s 12.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.5it/s 1.1s0.3s
#                    all        132       1992      0.679      0.608      0.667       0.38
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      5.28G      1.485      1.116      1.017        174        640: 100% ━━━━━━━━━━━━ 66/66 5.5it/s 12.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.3it/s 1.2s0.4s
#                    all        132       1992      0.696      0.693      0.714      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50       5.3G      1.467      1.089      1.008        241        640: 100% ━━━━━━━━━━━━ 66/66 5.7it/s 11.6s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.8it/s 1.0s0.3s
#                    all        132       1992      0.713      0.667       0.72       0.41
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      5.31G      1.451      1.085      1.016        128        640: 100% ━━━━━━━━━━━━ 66/66 5.7it/s 11.6s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.6it/s 1.1s0.3s
#                    all        132       1992      0.805      0.692      0.765      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      5.34G      1.458      1.054      1.006        201        640: 100% ━━━━━━━━━━━━ 66/66 5.5it/s 12.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4.8it/s 1.0s0.3s
#                    all        132       1992       0.76      0.684      0.735      0.423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      5.35G      1.458      1.037      1.009        102        640: 100% ━━━━━━━━━━━━ 66/66 5.5it/s 12.0s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 4
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      6.38G      1.232     0.7543     0.9441         75        640: 100% ━━━━━━━━━━━━ 66/66 5.2it/s 12.7s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 5.2it/s 1.0s0.3s
#                    all        132       1992      0.836      0.736      0.795      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50       6.4G      1.223     0.7343     0.9453        116        640: 100% ━━━━━━━━━━━━ 66/66 5.8it/s 11.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 5.3it/s 0.9s0.3s
#                    all        132       1992      0.862      0.741      0.814      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      6.41G      1.212     0.7153     0.9401         70        640: 100% ━━━━━━━━━━━━ 66/66 5.9it/s 11.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 5.0it/s 1.0s0.3s
#                    all        132       1992      0.833      0.728      0.795      0.479
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      6.43G      1.196     0.7082     0.9401        120        640: 100% ━━━━━━━━━━━━ 66/66 5.9it/s 11.2s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 5.1it/s 1.0s0.3s
#                    all        132       1992      0.844      0.751      0.816      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      6.44G      1.196     0.7004     0.9346        155        640: 100% ━━━━━━━━━━━━ 66/66 5.9it/s 11.1s0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 5.0it/s 1.0s0.3s
#                    all        132       1992      0.834      0.757      0.809      0.501
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      6.47G      1.192     0.6871     0.9361         76        640: 100% ━━━━━━━━━━━━ 66/66 5.8it/s 11.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 5.2it/s 1.0s0.3s
#                    all        132       1992       0.86      0.748      0.812      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      6.48G      1.166     0.6788     0.9308         64        640: 100% ━━━━━━━━━━━━ 66/66 5.7it/s 11.7s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 5.5it/s 0.9s0.3s
#                    all        132       1992      0.849      0.754      0.816      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50       6.5G      1.173     0.6751     0.9388        289        640: 100% ━━━━━━━━━━━━ 66/66 5.7it/s 11.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 5.0it/s 1.0s0.3s
#                    all        132       1992      0.845      0.761      0.815      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      6.51G      1.161     0.6657     0.9299        151        640: 100% ━━━━━━━━━━━━ 66/66 5.7it/s 11.6s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 5.6it/s 0.9s0.3s
#                    all        132       1992      0.849      0.762       0.82      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      6.54G      1.158     0.6694     0.9309        193        640: 100% ━━━━━━━━━━━━ 66/66 5.8it/s 11.5s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 5.3it/s 0.9s0.3s
#                    all        132       1992      0.852      0.756      0.819      0.509
#
# 50 epochs completed in 0.184 hours.
# Optimizer stripped from /kaggle/working/yolo-output/train/weights/last.pt, 6.2MB
# Optimizer stripped from /kaggle/working/yolo-output/train/weights/best.pt, 6.2MB
#
# Validating /kaggle/working/yolo-output/train/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.1it/s 2.3s0.6s
# invalid value encountered in less
# invalid value encountered in less
#                    all        132       1992      0.848      0.762      0.819      0.511
#               Airplane         37        367      0.953      0.879      0.931      0.548
#                   Boat         33        657      0.805      0.738      0.793      0.491
#                    Car         31        679      0.863       0.76      0.815      0.528
#                   Ship         52        289      0.771      0.671      0.737       0.48
# Speed: 0.1ms preprocess, 1.7ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to /kaggle/working/yolo-output/train
# Training started successfully!

# %%
from ultralytics import YOLO
from pathlib import Path

# --- 1. Define Paths ---
# Ensure these paths match your training setup
DATA = "/kaggle/working/Skysealand-2/data.yaml"
OUTPUT_FOLDER = Path("/kaggle/working/yolo-output")
# This assumes your training run was named "train" (from project=OUTPUT_FOLDER, name="train")
# If you used a different name, change "train" here.
TRAIN_RUN_PATH = OUTPUT_FOLDER / "train" 
BEST_WEIGHTS_PATH = TRAIN_RUN_PATH / "weights" / "best.pt"

# --- 2. Load the Best Model ---
# Load the best model weights saved during training
print(f"Loading best model from: {BEST_WEIGHTS_PATH}")
model = YOLO(BEST_WEIGHTS_PATH)

# --- 3. Evaluate on the Test Set ---
print("Evaluating model on the 'test' split...")
metrics = model.val(
    data=str(DATA),
    split="test",
    plots=True,                 # Save confusion matrix, P-R curve, etc.
    project=str(OUTPUT_FOLDER),
    name="test_evaluation"      # Saves results to /kaggle/working/yolo-output/test_evaluation
)

# --- 4. Extract, Calculate, and Print Metrics ---
print("Extracting metrics...")
map50_95 = metrics.box.map    # mAP@0.5:0.95
map50 = metrics.box.map50     # mAP@0.5
precision = metrics.box.mp    # Precision
recall = metrics.box.mr       # Recall

# Calculate F1 Score
# F1 = 2 * (Precision * Recall) / (Precision + Recall)
f1 = 2 * (precision * recall) / (precision + recall + 1e-6) # Add 1e-6 to avoid division by zero

# Print the results in a clean format
print("\n--- Test Set Evaluation Results ---")
print(f"Model: {str(BEST_WEIGHTS_PATH)}")
print(f"mAP@0.5:0.95: {map50_95:.4f}")
print(f"mAP@0.5       : {map50:.4f}")
print(f"Precision     : {precision:.4f}")
print(f"Recall        : {recall:.4f}")
print(f"F1 Score      : {f1:.4f}")
print("-----------------------------------")
# Out:
# Loading best model from: /kaggle/working/yolo-output/train/weights/best.pt
# Evaluating model on the 'test' split...
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2430.9±832.5 MB/s, size: 250.4 KB)
# val: Scanning /kaggle/working/Skysealand-2/test/labels... 127 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 127/127 1.3Kit/s 0.1s
# val: New cache created: /kaggle/working/Skysealand-2/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 8/8 2.7it/s 3.0s0.2s
# invalid value encountered in less
# invalid value encountered in less
#                    all        127       2075      0.839      0.755      0.833      0.496
#               Airplane         52        553      0.944      0.917      0.949      0.534
#                   Boat         23        334      0.754      0.719      0.781      0.478
#                    Car         24        798      0.834      0.742      0.832      0.508
#                   Ship         46        390      0.825      0.641      0.772      0.463
# Speed: 1.2ms preprocess, 5.9ms inference, 0.0ms loss, 10.1ms postprocess per image
# Results saved to /kaggle/working/yolo-output/test_evaluation
# Extracting metrics...
#
# --- Test Set Evaluation Results ---
# Model: /kaggle/working/yolo-output/train/weights/best.pt
# mAP@0.5:0.95: 0.4956
# mAP@0.5       : 0.8332
# Precision     : 0.8391
# Recall        : 0.7545
# F1 Score      : 0.7946
# -----------------------------------

# %%
# !pip install ttach
# Out:
# Collecting ttach
#   Downloading ttach-0.0.3-py3-none-any.whl.metadata (5.2 kB)
# Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Installing collected packages: ttach
# Successfully installed ttach-0.0.3

# %%
# !git clone https://github.com/rigvedrs/YOLO-V8-CAM.git
# Out:
# Cloning into 'YOLO-V8-CAM'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 168 (delta 39), reused 21 (delta 11), pack-reused 99 (from 2)
# Receiving objects: 100% (168/168), 52.67 MiB | 39.92 MiB/s, done.
# Resolving deltas: 100% (70/70), done.

# %%
import sys
sys.path.append("/kaggle/working/YOLO-V8-CAM")

# %%
# %cd /kaggle/working
# !rm -rf YOLO-V8-CAM
# !git clone https://github.com/rigvedrs/YOLO-V8-CAM.git
# Out:
# /kaggle/working
# Cloning into 'YOLO-V8-CAM'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 168 (delta 39), reused 21 (delta 11), pack-reused 99 (from 2)
# Receiving objects: 100% (168/168), 52.67 MiB | 40.86 MiB/s, done.
# Resolving deltas: 100% (70/70), done.

# %%
# %cd /kaggle/working/YOLO-V8-CAM
# !pip install -e .
# Out:
# /kaggle/working/YOLO-V8-CAM
# Obtaining file:///kaggle/working/YOLO-V8-CAM
# ERROR: file:///kaggle/working/YOLO-V8-CAM does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !ls /kaggle/working/YOLO-V8-CAM
# Out:
# images	     models	test	  YOLO_v11_EigenCAM.ipynb
# LICENSE.txt  README.md	yolo_cam  YOLO_v8n_EigenCAM.ipynb

# %%
import os, sys

print("Checking folder exists:")
print(os.path.exists("/kaggle/working/YOLO-V8-CAM"))
print(os.path.exists("/kaggle/working/YOLO-V8-CAM/yolo_cam"))

print("\nListing YOLO-V8-CAM:")
os.system("ls /kaggle/working/YOLO-V8-CAM")

print("\nListing yolo_cam:")
os.system("ls /kaggle/working/YOLO-V8-CAM/yolo_cam")

print("\nPython path BEFORE:")
print(sys.path)

sys.path.insert(0, "/kaggle/working/YOLO-V8-CAM")

print("\nPython path AFTER:")
print(sys.path)

try:
    import yolo_cam
    print("yolo_cam imported")
except Exception as e:
    print("IMPORT FAILED:", e)
# Out:
# Checking folder exists:
# True
# True
#
# Listing YOLO-V8-CAM:
# images
# LICENSE.txt
# models
# README.md
# test
# yolo_cam
# YOLO_v11_EigenCAM.ipynb
# YOLO_v8n_EigenCAM.ipynb
#
# Listing yolo_cam:
# activations_and_gradients.py
# base_cam.py
# eigen_cam.py
# __init__.py
# utils
#
# Python path BEFORE:
# ['/usr/local/lib/python3.11/dist-packages/ray/thirdparty_files', '/kaggle/working', '/kaggle/lib/kagglegym', '/kaggle/lib', '/usr/lib/python311.zip', '/usr/lib/python3.11', '/usr/lib/python3.11/lib-dynload', '', '/usr/local/lib/python3.11/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.11/dist-packages/IPython/extensions', '/root/.ipython', '/usr/local/lib/python3.11/dist-packages/setuptools/_vendor', '/tmp/tmp074nmkkp', '/kaggle/working/YOLO-V8-CAM']
#
# Python path AFTER:
# ['/kaggle/working/YOLO-V8-CAM', '/usr/local/lib/python3.11/dist-packages/ray/thirdparty_files', '/kaggle/working', '/kaggle/lib/kagglegym', '/kaggle/lib', '/usr/lib/python311.zip', '/usr/lib/python3.11', '/usr/lib/python3.11/lib-dynload', '', '/usr/local/lib/python3.11/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.11/dist-packages/IPython/extensions', '/root/.ipython', '/usr/local/lib/python3.11/dist-packages/setuptools/_vendor', '/tmp/tmp074nmkkp', '/kaggle/working/YOLO-V8-CAM']
# yolo_cam imported

# %%
import importlib.util
import sys

module_path = "/kaggle/working/YOLO-V8-CAM/yolo_cam/__init__.py"

spec = importlib.util.spec_from_file_location("yolo_cam", module_path)
yolo_cam = importlib.util.module_from_spec(spec)
sys.modules["yolo_cam"] = yolo_cam
spec.loader.exec_module(yolo_cam)

# Now load EigenCAM directly
spec2 = importlib.util.spec_from_file_location(
    "yolo_cam.eigen_cam",
    "/kaggle/working/YOLO-V8-CAM/yolo_cam/eigen_cam.py"
)
eigen_cam = importlib.util.module_from_spec(spec2)
sys.modules["yolo_cam.eigen_cam"] = eigen_cam
spec2.loader.exec_module(eigen_cam)

EigenCAM = eigen_cam.EigenCAM

print("EigenCAM manually loaded")
# Out:
# EigenCAM manually loaded

# %%
import sys
sys.path = ["/kaggle/working/YOLO-V8-CAM"] + sys.path

# %%
from ultralytics import YOLO

model = YOLO("/kaggle/working/yolo-output/train/weights/best.pt")
results = model.predict(source="image.jpg", conf=0.25)

# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image
from ultralytics import YOLO
from pathlib import Path

# --- 1. Define Paths ---
# Path to your test images
TEST_IMG_DIR = "/kaggle/working/Skysealand-2/test/images"
# Path to your best model weights
OUTPUT_FOLDER = Path("/kaggle/working/yolo-output")
TRAIN_RUN_PATH = OUTPUT_FOLDER / "train" 
BEST_WEIGHTS_PATH = TRAIN_RUN_PATH / "weights" / "best.pt"

# --- 2. Load the Best Model ---
print(f"Loading best model from: {BEST_WEIGHTS_PATH}")
model = YOLO(BEST_WEIGHTS_PATH)

# --- 3. Get Random Test Images ---
# Get all image files from the test directory
all_test_images = [f for f in os.listdir(TEST_IMG_DIR) if f.endswith(('.jpg', '.png', '.jpeg'))]

# Select 5 random images
# Set k=min(5, len(all_test_images)) to avoid errors if the test set has less than 5 images
num_to_display = min(5, len(all_test_images))
random_image_files = random.sample(all_test_images, num_to_display)

# Create full paths
image_paths = [os.path.join(TEST_IMG_DIR, f) for f in random_image_files]

# --- 4. Run Prediction ---
print(f"Running predictions on {num_to_display} random images...")
# conf=0.25 means only boxes with 25% confidence or higher will be shown
results = model.predict(source=image_paths, conf=0.25)

# --- 5. Display Results ---
print("Displaying predictions (images include bounding boxes, labels, and confidence scores):")
for i, r in enumerate(results):
    # r.plot() returns a BGR numpy array with the boxes, labels, and scores plotted
    # We convert it to RGB for correct display with matplotlib
    img_with_boxes_rgb = r.plot(pil=True) # Use pil=True to get a PIL Image

    plt.figure(figsize=(10, 10))
    plt.imshow(img_with_boxes_rgb)
    plt.title(f"Prediction for: {random_image_files[i]}")
    plt.axis('off')
    plt.show()
# Out:
# Loading best model from: /kaggle/working/yolo-output/train/weights/best.pt
# Running predictions on 5 random images...
#
# 0: 640x640 18 Airplanes, 2 Cars, 8.3ms
# 1: 640x640 42 Cars, 8.3ms
# 2: 640x640 18 Airplanes, 8.3ms
# 3: 640x640 11 Airplanes, 8.3ms
# 4: 640x640 17 Ships, 8.3ms
# Speed: 2.3ms preprocess, 8.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Displaying predictions (images include bounding boxes, labels, and confidence scores):

# %%
import os
import random
import cv2
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO

# --- Load trained model ---
BEST_WEIGHTS_PATH = "/kaggle/working/yolo-output/train/weights/best.pt"
model = YOLO(BEST_WEIGHTS_PATH)

# --- Choose CAM Layer ---
target_layer = model.model.model[-2]   # best deep layer for YOLOv8 CAM

# --- Get a random test image ---
TEST_IMG_DIR = "/kaggle/working/Skysealand-2/test/images"
images = [f for f in os.listdir(TEST_IMG_DIR) if f.lower().endswith(('.jpg','.png','.jpeg'))]

if not images:
    raise Exception("No images found in test directory!")

img_name = random.choice(images)
img_path = os.path.join(TEST_IMG_DIR, img_name)

# --- Load image ---
img_bgr = cv2.imread(img_path)
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

print("Running EigenCAM on:", img_name)

# --- Run YOLO prediction ---
results = model(img_rgb, verbose=False)

# --- Run EigenCAM ---
cam = EigenCAM(model=model, target_layers=[target_layer], task='od')
grayscale_cam = cam(img_rgb)[0]  

# --- Resize CAM ---
grayscale_cam = cv2.resize(grayscale_cam, (img_rgb.shape[1], img_rgb.shape[0]))

# --- Normalize CAM ---
cam_norm = (grayscale_cam - grayscale_cam.min()) / (grayscale_cam.max() - grayscale_cam.min() + 1e-8)
heatmap = cv2.applyColorMap(np.uint8(255 * cam_norm), cv2.COLORMAP_JET)
heatmap = cv2.cvtColor(heatmap, cv2.COLOR_BGR2RGB)

# --- Overlay ---
overlay = cv2.addWeighted(img_rgb, 0.6, heatmap, 0.4, 0)

# --- Plot detections ---
det = results[0].plot()
det = cv2.cvtColor(det, cv2.COLOR_BGR2RGB)

# --- Show ---
fig, ax = plt.subplots(1, 2, figsize=(18, 8))

ax[0].imshow(det)
ax[0].set_title("YOLO Detection")
ax[0].axis("off")

ax[1].imshow(overlay)
ax[1].set_title("EigenCAM Heatmap")
ax[1].axis("off")

plt.show()
# Out:
# Running EigenCAM on: sample_01055_jpg.rf.e96a464fd97300a861e1298de5c4641e.jpg

# %%
import yaml

DATA = "/kaggle/working/Skysealand-2/data.yaml"

with open(DATA, "r") as f:
    data_cfg = yaml.safe_load(f)

names = data_cfg["names"]          
num_classes = len(names)

print("Classes:")
for cid, cname in enumerate(names):
    print(cid, "->", cname)
# Out:
# Classes:
# 0 -> Airplane
# 1 -> Boat
# 2 -> Car
# 3 -> Ship

# %%
import os, cv2
import numpy as np
from ultralytics import YOLO

names = ["Airplane", "Boat", "Car", "Ship"]
BEST_WEIGHTS_PATH = "/kaggle/working/yolo-output/train/weights/best.pt"
TEST_IMG_DIR = "/kaggle/working/Skysealand-2/test/images"
OUT_DET_DIR = "/kaggle/working/yolo-output/test_dets"
os.makedirs(OUT_DET_DIR, exist_ok=True)

model = YOLO(BEST_WEIGHTS_PATH)

class_counts = {cid: 0 for cid in range(len(names))}

images
# Out:
# ['sample_01121_jpg.rf.5a06078a417c3818bec8dbd5d681356c.jpg',
#  'sample_01068_jpg.rf.9bac4f1861a5c42b4e8f808f8ee80896.jpg',
#  'sample_01173_jpg.rf.dbfa17b779777cd9ec80c3f0fed6b9a1.jpg',
#  'sample_01141_jpg.rf.5b5604828af261ffa9d3f786380beff6.jpg',
#  'sample_01058_jpg.rf.bb9f866d6a0f72e081781196a70d8451.jpg',
#  'sample_01085_jpg.rf.3f79be8d0408b00c6650f1dc6a3cff63.jpg',
#  'sample_01112_jpg.rf.61d669b20cc7b972eb29ac1397162e77.jpg',
#  'sample_01139_jpg.rf.be045f2876b7edb5caff38559f0fe439.jpg',
#  'sample_01169_jpg.rf.3c5189275dcc213139e2e041e33ffc1a.jpg',
#  'sample_01162_jpg.rf.6f55234e2c18e640add64e1f7e9a9ffd.jpg',
#  'sample_01148_jpg.rf.c4d5084f282cb761dae486f6c167eee3.jpg',
#  'sample_01128_jpg.rf.a836097a1c27f54088d40b617dd3099a.jpg',
#  'sample_01097_jpg.rf.dabe2993d677f83048c09c1305e7ae59.jpg',
#  'sample_01089_jpg.rf.29b01454c57ac961ed1160cc95e29986.jpg',
#  'sample_01083_jpg.rf.d6ac7a1c4d257cbbda232b8aa307be64.jpg',
#  'sample_01075_jpg.rf.b8614de59e8908d98c58843d38c9ead0.jpg',
#  'sample_01160_jpg.rf.193381b5da5e6aeb35ae5141ad96c29a.jpg',
#  'sample_01096_jpg.rf.c9d2f1a00e457d9d914caeefeda9d950.jpg',
#  'sample_01146_jpg.rf.07488c68dfe716705b02aaf12e9fab19.jpg',
#  'sample_01152_jpg.rf.afd0d5b8c08ce5bf51276ba887bb2630.jpg',
#  'sample_01145_jpg.rf.9ea23010bfa39249f09b69313d1aba63.jpg',
#  'sample_01070_jpg.rf.fe803b54d3bf4a3a04c4571849457ab5.jpg']

# %%
import os, cv2
import numpy as np
from ultralytics import YOLO

names = ["Airplane", "Boat", "Car", "Ship"]
BEST_WEIGHTS_PATH = "/kaggle/working/yolo-output/train/weights/best.pt"
TEST_IMG_DIR = "/kaggle/working/Skysealand-2/test/images"
OUT_DET_DIR = "/kaggle/working/yolo-output/test_dets"
os.makedirs(OUT_DET_DIR, exist_ok=True)

model = YOLO(BEST_WEIGHTS_PATH)

class_counts = {cid: 0 for cid in range(len(names))}

images = [f for f in os.listdir(TEST_IMG_DIR)
          if f.lower().endswith((".jpg", ".jpeg", ".png"))]

for img_name in images:
    img_path = os.path.join(TEST_IMG_DIR, img_name)
    img_bgr = cv2.imread(img_path)
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

    results = model(img_rgb, verbose=False)
    r = results[0]

    if r.boxes is not None:
        cls_ids = r.boxes.cls.cpu().numpy().astype(int)
        for cid in cls_ids:
            class_counts[cid] += 1

    det_img = r.plot()  # BGR
    save_path = os.path.join(OUT_DET_DIR, f"det_{img_name}")
    cv2.imwrite(save_path, det_img)

print("\n=== Class‑wise detection summary ===")
for cid, cnt in class_counts.items():
    print(f"{cid} ({names[cid]}): {cnt} detections")
# Out:
# === Class‑wise detection summary ===
# 0 (Airplane): 552 detections
# 1 (Boat): 407 detections
# 2 (Car): 656 detections
# 3 (Ship): 417 detections

# %%
# CLASSIFICATION OUTPUT BLOCK

class_names = ['airplane', 'boat', 'car', 'ship']

boxes = results[0].boxes.xyxy.cpu().numpy()
cls_ids = results[0].boxes.cls.cpu().numpy().astype(int)
scores = results[0].boxes.conf.cpu().numpy()

if len(boxes) == 0:
    print("No objects detected")

print("\n CLASSIFICATION RESULTS")
print("-"*45)

for i, (box, cls_id, score) in enumerate(zip(boxes, cls_ids, scores)):
    name = class_names[cls_id]
    x1, y1, x2, y2 = map(int, box)

    print(f"Object {i+1}")
    print(f"   Class      : {name}")
    print(f"   Confidence : {score:.4f}")
    print(f"   BBox       : ({x1},{y1}) → ({x2},{y2})")
    print("-"*45)
# Out:
#  CLASSIFICATION RESULTS
# ---------------------------------------------
# Object 1
#    Class      : airplane
#    Confidence : 0.8508
#    BBox       : (641,244) → (750,344)
# ---------------------------------------------
# Object 2
#    Class      : airplane
#    Confidence : 0.8469
#    BBox       : (681,313) → (795,438)
# ---------------------------------------------
# Object 3
#    Class      : airplane
#    Confidence : 0.8234
#    BBox       : (508,266) → (635,407)
# ---------------------------------------------
# Object 4
#    Class      : airplane
#    Confidence : 0.8154
#    BBox       : (564,141) → (682,277)
# ---------------------------------------------
# Object 5
#    Class      : airplane
#    Confidence : 0.8114
#    BBox       : (887,542) → (1035,657)
# ---------------------------------------------
# Object 6
#    Class      : airplane
#    Confidence : 0.8099
#    BBox       : (975,296) → (1077,387)
# ---------------------------------------------
# Object 7
#    Class      : airplane
#    Confidence : 0.8067
#    BBox       : (830,325) → (935,425)
# ---------------------------------------------
# Object 8
#    Class      : airplane
#    Confidence : 0.7832
#    BBox       : (940,372) → (1046,469)
# ---------------------------------------------
# Object 9
#    Class      : airplane
#    Confidence : 0.7801
#    BBox       : (710,196) → (830,307)
# ---------------------------------------------
# Object 10
#    Class      : airplane
#    Confidence : 0.7438
#    BBox       : (863,253) → (961,337)
# ---------------------------------------------
# Object 11
#    Class      : airplane
#    Confidence : 0.6775
#    BBox       : (817,211) → (876,283)
# ---------------------------------------------

# %%
import pandas as pd

data = []

for box, cls_id, score in zip(boxes, cls_ids, scores):
    x1,y1,x2,y2 = map(int, box)
    data.append([class_names[cls_id], score, x1,y1,x2,y2])

df = pd.DataFrame(data, columns=["Class", "Confidence", "x1", "y1", "x2", "y2"])
df.to_csv("/kaggle/working/classification_results.csv", index=False)

print("Saved classification_results.csv")
# Out:
# Saved classification_results.csv

# %%
print(df.columns.tolist())
# Out:
# ['Class', 'Confidence', 'x1', 'y1', 'x2', 'y2']

# %%
import pandas as pd
import matplotlib.pyplot as plt

csv_path = "/kaggle/working/yolo-output/train/results.csv"
df = pd.read_csv(csv_path)

# Try to detect epoch column automatically
epoch_col = None
for c in df.columns:
    if "epoch" in c.lower():
        epoch_col = c
        break

if epoch_col is None:
    raise ValueError("No epoch-like column found! Printing columns:", df.columns)

print("Detected epoch column:", epoch_col)

plt.figure(figsize=(12,6))
plt.plot(df[epoch_col], df["train/box_loss"] + df["train/cls_loss"] + df["train/dfl_loss"], label="Train Total Loss")
plt.plot(df[epoch_col], df["val/box_loss"] + df["val/cls_loss"] + df["val/dfl_loss"], label="Val Total Loss")
plt.xlabel("Epoch")
plt.ylabel("Total Loss")
plt.title("YOLO Total Loss Curve")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Detected epoch column: epoch

# %%
import os

base = "/kaggle/working"

dataset_dir = [d for d in os.listdir(base) if d.lower().startswith("sky")][0]
dataset_path = f"{base}/{dataset_dir}"

print("Dataset folder detected:", dataset_path)

yaml_path = f"{dataset_path}/data.yaml"

yaml_content = f"""
train: {dataset_path}/train/images
val: {dataset_path}/valid/images
test: {dataset_path}/test/images

nc: 4
names:
  - Airplane
  - Boat
  - Car
  - Ship
"""

with open(yaml_path, "w") as f:
    f.write(yaml_content)

print("✅ data.yaml written to:", yaml_path)
# Out:
# Dataset folder detected: /kaggle/working/Skysealand-2
# ✅ data.yaml written to: /kaggle/working/Skysealand-2/data.yaml

# %%
from pathlib import Path
from ultralytics import YOLO
import yaml

# ============================================================
# TRAINING HYPERPARAMETERS
# ============================================================
EPOCHS = 100
BATCH_SIZE = 16
IMAGE_SIZE = 640
PATIENCE = 10
DEVICE = 0

# ============================================================
# BASE DATASET (READ-ONLY)
# ============================================================
BASE = Path("/kaggle/input/skysealand-2")

# ============================================================
# WORKING DIRECTORY (WRITEABLE)
# ============================================================
WORK = Path("/kaggle/working/skysealand_yolov12_ssl")
WORK.mkdir(parents=True, exist_ok=True)

# ============================================================
# YOLO DATA YAML PATH
# ============================================================
DATA = WORK / "data_skysealand.yaml"

# ============================================================
# CREATE data_skysealand.yaml (REQUIRED)
# ============================================================
data_yaml = {
    "path": str(BASE),
    "train": "train/images",
    "val": "valid/images",   # change to val/images if needed
    "test": "test/images",
    "nc": 1,                 # change if more classes
    "names": ["object"]      # change to real class name
}

with open(DATA, "w") as f:
    yaml.safe_dump(data_yaml, f, sort_keys=False)

print("YAML created at:", DATA)

# ============================================================
# YOLOv12s TEACHER MODEL TRAINING
# ============================================================
PROJECT = str(WORK / "skysealand_yolov12s_ssl_labeled")
NAME = "yolov12s_skysealand_ssl_labeled"

model = YOLO("yolo12s.pt")

results = model.train(
    data=str(DATA),
    epochs=EPOCHS,
    imgsz=IMAGE_SIZE,
    batch=BATCH_SIZE,
    device=DEVICE,
    patience=PATIENCE,
    workers=2,
    project=PROJECT,
    name=NAME,
    exist_ok=True
)

# ============================================================
# BEST MODEL PATH
# ============================================================
BEST_WEIGHTS = Path(PROJECT) / NAME / "weights" / "best.pt"
print("Best trained weights saved at:", BEST_WEIGHTS)
# Out:
# YAML created at: /kaggle/working/skysealand_yolov12_ssl/data_skysealand.yaml
# Ultralytics 8.3.237 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/skysealand_yolov12_ssl/data_skysealand.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov12s_skysealand_ssl_labeled, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/skysealand_yolov12_ssl/skysealand_yolov12s_ssl_labeled, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/skysealand_yolov12_ssl/skysealand_yolov12s_ssl_labeled/yolov12s_skysealand_ssl_labeled, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/trainer.py in get_dataset(self)
#     648             }:
# --> 649                 data = check_det_dataset(self.args.data)
#     650                 if "yaml_file" in data:
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/data/utils.py in check_det_dataset(dataset, autodownload)
#     461                 m += f"\nNote dataset download directory is '{DATASETS_DIR}'. You can update this in '{SETTINGS_FILE}'"
# --> 462                 raise FileNotFoundError(m)
#     463             t = time.time()
#
# FileNotFoundError: Dataset '/kaggle/working/skysealand_yolov12_ssl/data_skysealand.yaml' images not found, missing path '/kaggle/input/skysealand-2/valid/images'
# Note dataset download directory is '/kaggle/working/datasets'. You can update this in '/root/.config/Ultralytics/settings.json'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_47/842010681.py in <cell line: 0>()
#      53 model = YOLO("yolo12s.pt")
#      54
# ---> 55 results = model.train(
#      56     data=str(DATA),
#      57     epochs=EPOCHS,
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     766             args["resume"] = self.ckpt_path
#     767
# --> 768         self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     769         if not args.get("resume"):  # manually set model only if not resuming
#     770             self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/models/yolo/detect/train.py in __init__(self, cfg, overrides, _callbacks)
#      61             _callbacks (list, optional): List of callback functions to be executed during training.
#      62         """
# ---> 63         super().__init__(cfg, overrides, _callbacks)
#      64
#      65     def build_dataset(self, img_path: str, mode: str = "train", batch: int | None = None):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/trainer.py in __init__(self, cfg, overrides, _callbacks)
#     161         self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     162         with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 163             self.data = self.get_dataset()
#     164
#     165         self.ema = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/trainer.py in get_dataset(self)
#     651                     self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     652         except Exception as e:
# --> 653             raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     654         if self.args.single_cls:
#     655             LOGGER.info("Overriding class names with single class.")
#
# RuntimeError: Dataset '/kaggle/working/skysealand_yolov12_ssl/data_skysealand.yaml' error ❌ Dataset '/kaggle/working/skysealand_yolov12_ssl/data_skysealand.yaml' images not found, missing path '/kaggle/input/skysealand-2/valid/images'
# Note dataset download directory is '/kaggle/working/datasets'. You can update this in '/root/.config/Ultralytics/settings.json'
